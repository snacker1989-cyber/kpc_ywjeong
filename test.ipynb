# %%
import importlib
import RAGbuilder
importlib.reload(RAGbuilder)

from RAGbuilder import load_and_split

def debug_chunks(pdf_path):
    docs = load_and_split(pdf_path)
    print(f"📄 파일명: {pdf_path}")
    print(f"✂️ 총 생성된 청크 수: {len(docs)}개")
    print("-" * 50)

    for i, doc in enumerate(docs[:5]):  # 처음 5개만 확인
        content = doc.page_content.replace("\n", " ")
        print(f"[Chunk {i}]")
        print(f"📏 길이: {len(doc.page_content)}자")
        print(f"📝 내용: {content[:200]}...") # 앞부분 200자만 출력
        
        # overlap 확인을 위해 다음 청크 시작 부분 보여주기
        if i < len(docs) - 1:
            next_start = docs[i+1].page_content[:30].replace("\n", " ")
            print(f"🔗 다음 청크와의 연결부: ... [{next_start}]")
        
        print("-" * 50)

# %%
if __name__ == "__main__":
    test_pdf = "data/(4-02) 인사규정_260121.pdf"
    debug_chunks(test_pdf)
# Out:
# 📄 파일명: data/(4-02) 인사규정_260121.pdf
# ✂️ 총 생성된 청크 수: 62개
# --------------------------------------------------
# [Chunk 0]
# 📏 길이: 490자
# 📝 내용: 인사규정 인사관리 4-02 - 1 - 인 사 규 정 제정: 1986. 7. 1. 개정: 1987. 2. 1. 개정: 1987. 7. 1. 개정: 1988. 1. 17. 개정: 1988. 5. 31. 개정: 1988. 9. 1. 개정: 1988. 11. 17. 개정: 1989. 11. 22. 개정: 1990. 1. 1. 개정: 1991. 5. 1. 개정: 1...
# 🔗 다음 청크와의 연결부: ... [개정: 1997. 8. 25. 개정: 1998. 7. ]
# --------------------------------------------------
# [Chunk 1]
# 📏 길이: 494자
# 📝 내용: 개정: 1997. 8. 25. 개정: 1998. 7. 1. 개정: 2000. 8. 9. 개정: 2001. 3. 1. 개정: 2002. 8. 1. 개정: 2003. 4. 1. 개정: 2003. 10. 20. 개정: 2004. 1. 1. 개정: 2005. 1. 1. 개정: 2005. 1. 21. 개정: 2005. 10. 19. 개정: 2007. 4. 23. 개...
# 🔗 다음 청크와의 연결부: ... [개정: 2014. 9. 1. 개정: 2014. 9. 2]
# --------------------------------------------------
# [Chunk 2]
# 📏 길이: 493자
# 📝 내용: 개정: 2014. 9. 1. 개정: 2014. 9. 22. 개정: 2015. 1. 1. 개정: 2015. 9. 1. 개정: 2015. 12. 28. 개정: 2016. 1. 1. 개정: 2017. 1. 1. 개정: 2017. 12. 7. 개정: 2019. 1. 21. 개정: 2020. 1. 1. 개정: 2020. 5. 6. 개정: 2020. 6. 1. 개정:...
# 🔗 다음 청크와의 연결부: ... [개정 . (2001.3.1.  ) 제조 적용범위 2 (]
# --------------------------------------------------
# [Chunk 3]
# 📏 길이: 275자
# 📝 내용: 개정 . (2001.3.1.  ) 제조 적용범위 2 ( ) 직원의 인사에 관한 사항은 정관 또는 타 규정에 따로 정하는 것을 제외하고는    이 규정이 정하는 바에 따른다. 제조용어의 정의 3 ( ) 이 규정에서 사용하는 용어의 정의는 다음과 같다   . 직원이라 함은 인사발령에 의하여 본부에 근무하는 임원을 제외한 근무자를 말한다 1. “ ” . 삭제  ...
# 🔗 다음 청크와의 연결부: ... [인사규정 인사관리 4-02 - 2 - 신설 1.  ) ]
# --------------------------------------------------
# [Chunk 4]
# 📏 길이: 474자
# 📝 내용: 인사규정 인사관리 4-02 - 2 - 신설 1.  ) 직급이라 함은 직원을 직무와 책임의 정도 및 난이도에 따라 구분하는 것을 말한다 4. “ ” . 직위라 함은 직급에 따라 직원에게 부여하는 직명을 말한다 개정 5. “ ” . (2001.3.1.  ) 직책이라 함은 직무 및 권한의 한계와 책임의 정도에 따라 부여하는 직명을 말한다 5-1. “ ” . (2...
# 🔗 다음 청크와의 연결부: ... [8. “ ” . 삭제  9.  (2017.1.1.) 승]
# --------------------------------------------------
