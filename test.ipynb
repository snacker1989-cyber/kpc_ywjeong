# %%
import importlib
import RAGbuilder
importlib.reload(RAGbuilder)

from RAGbuilder import load_and_split_md

def debug_chunks(pdf_path):
    docs = load_and_split_md(pdf_path)
    print(f"📄 파일명: {pdf_path}")
    print(f"✂️ 총 생성된 청크 수: {len(docs)}개")
    print("-" * 50)

    for i, doc in enumerate(docs[:5]):  # 처음 5개만 확인
        content = doc.page_content.replace("\n", " ")
        print(f"[Chunk {i}]")
        print(f"📏 길이: {len(doc.page_content)}자")
        print(f"📝 내용: {content[:200]}...") # 앞부분 200자만 출력
        
        # overlap 확인을 위해 다음 청크 시작 부분 보여주기
        if i < len(docs) - 1:
            next_start = docs[i+1].page_content[:30].replace("\n", " ")
            print(f"🔗 다음 청크와의 연결부: ... [{next_start}]")
        
        print("-" * 50)

# %%
if __name__ == "__main__":
    test_pdf = "data/(4-01) 취업규칙_260121.md"
    debug_chunks(test_pdf)
# Out:
# 📄 파일명: data/(4-01) 취업규칙_260121.md
# ✂️ 총 생성된 청크 수: 90개
# --------------------------------------------------
# [Chunk 0]
# 📏 길이: 278자
# 📝 내용: 제1조(목적) 이 규칙은 근로기준법 및 노동관계법에 따라 한국생산성본부(이하 “본부”라 한다)에서 근무하는 직원의 임용, 인사, 복무, 보수 등 근로조건에 관한 사항을 정함을 목적으로 한다.   제2조(적용범위) 이 규칙은 본부에서 근무하는 모든 직원에게 적용한다.   제3조(신의성실의 의무) 본부와 직원은 이 규칙에서 정한 사항과 관계법령을 준수하도록 성...
# 🔗 다음 청크와의 연결부: ... [제5조(채용결격사유) * ① 다음 각 호의 어느 하나에]
# --------------------------------------------------
# [Chunk 1]
# 📏 길이: 260자
# 📝 내용: 제5조(채용결격사유) * ① 다음 각 호의 어느 하나에 해당하는 자는 직원으로 채용될 수 없다. 단, 고용계약 체결 후에 다음 각 호의 하나에 해당하는 사실이 확인될 때는 직권으로 면직한다. 1. 피성년후견인 또는 피한정후견인 2. 파산자로서 복권되지 아니한 자 3. 금고 이상의 실형을 선고받고 그 집행이 종료되거나 집행을 받지 아니하기로 확정된 후 5년이...
# 🔗 다음 청크와의 연결부: ... [4. 금고 이상의 형을 선고받고 그 집행유예 기간이 끝]
# --------------------------------------------------
# [Chunk 2]
# 📏 길이: 262자
# 📝 내용: 4. 금고 이상의 형을 선고받고 그 집행유예 기간이 끝난 날부터 2년이 지나지 아니한 자 5. 금고 이상의 형의 선고유예를 받은 경우에 그 선고유예 기간 중에 있는 자 6. 법원의 판결 또는 다른 법률에 따라 자격이 상실되거나 정지된 자 7. 본부 또는 타사 재직기간 중 직무와 관련하여 횡령, 배임의 죄를 범한 자로서 300만 원 이상의 벌금형을 선고받고 ...
# 🔗 다음 청크와의 연결부: ... [8. 병역의무를 기피한 자 9. 신체검사결과 부적격 판]
# --------------------------------------------------
# [Chunk 3]
# 📏 길이: 282자
# 📝 내용: 8. 병역의무를 기피한 자 9. 신체검사결과 부적격 판정을 받은 자 10. 「부패방지 및 국민권익위원회의 설치와 운영에 관한 법률」 제82조에 따른 비위면직자 등의 취업제한 적용을 받는 자로 퇴직일 또는 형의 선고를 받은 경우 그 집행이 종료되거나 집행을 받지 아니하기로 확정된 날부터 5년이 지나지 않은 자 * ② 채용비리와 관련하여 유죄판결이 확정된 경우...
# 🔗 다음 청크와의 연결부: ... [제6조(수습기간) * ① 신규 채용된 자는 채용된 날로]
# --------------------------------------------------
# [Chunk 4]
# 📏 길이: 249자
# 📝 내용: 제6조(수습기간) * ① 신규 채용된 자는 채용된 날로부터 3개월간을 수습기간으로 한다. 다만, 본부가 필요하다고 인정하는 경우에는 합리적인 범위 내에서 그 기간을 단축하거나 연장할 수 있다. * ② 수습기간 중 또는 수습기간 만료 시 능력, 품행, 근무태도, 건강상태 및 직장적응성 등에 대하여 본채용이 부당하다고 인정되는 자의 수습기간 후 본채용 여부에 ...
# 🔗 다음 청크와의 연결부: ... [* ③ 수습기간 동안의 근무평가는 매월 1회 실시한다.]
# --------------------------------------------------
